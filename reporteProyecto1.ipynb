# %% [markdown]
# # 🔍 Proyecto: Resolución del Come Solo (Peg Solitaire) con Búsqueda en Árbol
#
# Este reporte documenta el desarrollo del algoritmo de búsqueda para resolver el rompecabezas *Come Solo*, utilizando la librería **baile** como base. Se definen los elementos formales del problema y se implementan y comparan tres algoritmos:
#
# - **BFS (Breadth-First Search)** — Búsqueda en amplitud.
# - **DFS (Depth-First Search)** — Búsqueda en profundidad.
# - **A\*** — Búsqueda informada con heurística.
#
# La meta del juego es reducir el tablero a una sola ficha, idealmente en el centro.

# %% [markdown]
# ## 1️⃣ Definición formal del problema
#
# - **Estado:** Representa la configuración del tablero (7×7) donde cada casilla puede estar vacía (`0`), ocupada (`1`), o fuera del tablero (`-1`).
# - **Operación sucesor:** Mover una ficha saltando sobre otra adyacente (horizontal o verticalmente) hacia un espacio vacío, eliminando la ficha intermedia.
# - **Condición de meta:** Quedar con una sola ficha, idealmente ubicada en el centro.
# - **Heurística:** La heurística `center_dist` suma el número de fichas restantes y su distancia Manhattan al centro del tablero, dando preferencia a configuraciones más “compactas” hacia la meta.

# %%
# Imports iniciales para el reporte Peg Solitaire
from src.peg_solitaire_problem import PegSolitaireProblem, run_experiments, board_str
import pandas as pd

# %% [markdown]
# ## 2️⃣ Ejecución de experimentos con BFS, DFS y A*
#
# Se comparan los tres algoritmos bajo los mismos parámetros:
# - Meta en el centro (`goal='center'`).
# - Heurística mejorada (`center_dist`).
# - Límite DFS = 100.
# - Tiempo máximo = 20 segundos.

# %%
# Comparativa BFS / DFS / A*
tabla = run_experiments(goal='center', heuristic_name='center_dist', depth_limit=100)
df = pd.DataFrame(tabla)
df

# %% [markdown]
# ## 3️⃣ Ejemplo paso a paso con A*
# Se ejecuta A* para mostrar los tableros intermedios desde el estado inicial hasta la meta (si se encuentra).

# %%
prob = PegSolitaireProblem(goal='center', heuristic_name='center_dist', algorithm='astar')
res = prob.solve()
if res.get('found'):
    print(f"Movimientos totales: {len(res['path'])}\n")
    for step, board in enumerate(res['boards']):
        print(f"Paso {step}:\n{board_str(board)}\n")
else:
    print("A* no alcanzó la meta en los límites dados.")

# %% [markdown]
# ## 4️⃣ Conclusiones y observaciones
#
# - **BFS** explora exhaustivamente por niveles, pero consume mucha memoria; ideal para tableros pequeños.
# - **DFS** avanza profundo en el árbol, pero puede atascarse; no garantiza encontrar la mejor solución.
# - **A\*** utiliza una heurística que guía la búsqueda hacia el centro, encontrando soluciones óptimas más rápido.
#
# **Conclusión general:** El algoritmo A* resulta el más eficiente al resolver el *Come Solo* bajo esta configuración, equilibrando exploración y costo estimado.
